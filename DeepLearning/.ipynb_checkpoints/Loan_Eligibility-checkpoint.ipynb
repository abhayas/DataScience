# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("lending_club_loan_two.csv")

# %%
df.head(1)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  emp_title  \
# 0    10000.0   36 months     11.44       329.48     B        B4  Marketing
#
#   emp_length home_ownership  annual_inc  ... open_acc pub_rec revol_bal  \
# 0  10+ years           RENT    117000.0  ...     16.0     0.0   36369.0
#
#   revol_util total_acc  initial_list_status application_type  mort_acc  \
# 0       41.8      25.0                    w       INDIVIDUAL       0.0
#
#    pub_rec_bankruptcies                                       address
# 0                   0.0  0174 Michelle Gateway\nMendozaberg, OK 22690
#
# [1 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
#  14  title                 394274 non-null  object
#  15  dti                   396030 non-null  float64
#  16  earliest_cr_line      396030 non-null  object
#  17  open_acc              396030 non-null  float64
#  18  pub_rec               396030 non-null  float64
#  19  revol_bal             396030 non-null  float64
#  20  revol_util            395754 non-null  float64
#  21  total_acc             396030 non-null  float64
#  22  initial_list_status   396030 non-null  object
#  23  application_type      396030 non-null  object
#  24  mort_acc              358235 non-null  float64
#  25  pub_rec_bankruptcies  395495 non-null  float64
#  26  address               396030 non-null  object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %%
sns.countplot(data=df, x="loan_status")
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.histplot(data=df, x="loan_amnt", bins=30)
# Out:
# c:\Users\saras\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='loan_amnt', ylabel='Count'>

# %%
df["term"] = pd.to_numeric(df["term"].apply(lambda x : x.split()[0]))

# %%
dfonlynumber = df.select_dtypes(include='number').corr()

# %%
sns.heatmap(data=dfonlynumber, cmap='coolwarm', fmt=".2f")
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x="loan_status", y="loan_amnt")
# Out:
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %%
df.groupby("loan_status").describe()
# Out:
#             loan_amnt                                                      \
#                 count          mean          std     min     25%      50%
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                                    term             ... mort_acc        \
#                  75%      max     count       mean  ...      75%   max
# loan_status                                         ...
# Charged Off  20000.0  40000.0   77673.0  45.279827  ...      2.0  23.0
# Fully Paid   19225.0  40000.0  318357.0  40.824169  ...      3.0  34.0
#
#             pub_rec_bankruptcies
#                            count      mean       std  min  25%  50%  75%  max
# loan_status
# Charged Off              77586.0  0.128412  0.368853  0.0  0.0  0.0  0.0  8.0
# Fully Paid              317909.0  0.119997  0.352992  0.0  0.0  0.0  0.0  8.0
#
# [2 rows x 104 columns]

# %%
grades = list(df["grade"].unique())

# %%
grades.sort()

# %%
grades
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
subgrades = list(df["sub_grade"].unique())

# %%
subgrades.sort()

# %%
subgrades
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5']

# %%
sortedbysubgrade = df.sort_values(by="sub_grade")
sns.countplot(data=sortedbysubgrade, x="grade", hue="loan_status")
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
#sortedbysubgrade

# %%
plt.figure()
sns.countplot(data=sortedbysubgrade, x="sub_grade", hue="loan_status")
plt.title('Default-Sized Countplotr')
plt.figure(figsize=(12,6))
plt.show()

# %%
subgradefng = ["F1","F2","F3","F4","F5","G1","G2","G3","G4","G5"]

# %%
plt.figure()
sns.countplot(data=sortedbysubgrade[sortedbysubgrade["sub_grade"].isin(subgradefng).sort_values()], x="sub_grade", hue="loan_status")
plt.title('Default-Sized Countplotr')
plt.figure(figsize=(12,6))
plt.show()
# Out:
# C:\Users\saras\AppData\Local\Temp\ipykernel_5864\2259839118.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.countplot(data=sortedbysubgrade[sortedbysubgrade["sub_grade"].isin(subgradefng).sort_values()], x="sub_grade", hue="loan_status")

# %%
df = pd.get_dummies(df,columns=["loan_status"], drop_first=True, dtype=int)

# %%
sns.heatmap(df.isna())
# Out:
# <Axes: >

# %%
round(df.isna().sum()/len(df)*100,2).sort_values(ascending=False)
# Out:
# mort_acc                  9.54
# emp_title                 5.79
# emp_length                4.62
# title                     0.44
# pub_rec_bankruptcies      0.14
# revol_util                0.07
# earliest_cr_line          0.00
# address                   0.00
# application_type          0.00
# initial_list_status       0.00
# total_acc                 0.00
# revol_bal                 0.00
# pub_rec                   0.00
# open_acc                  0.00
# loan_amnt                 0.00
# dti                       0.00
# term                      0.00
# purpose                   0.00
# issue_d                   0.00
# verification_status       0.00
# annual_inc                0.00
# home_ownership            0.00
# sub_grade                 0.00
# grade                     0.00
# installment               0.00
# int_rate                  0.00
# loan_status_Fully Paid    0.00
# dtype: float64

# %%
df.drop("title", inplace=True, axis=1)

# %%
df.head(1)
# Out:
#    loan_amnt  term  int_rate  installment grade sub_grade  emp_title  \
# 0    10000.0    36     11.44       329.48     B        B4  Marketing
#
#   emp_length home_ownership  annual_inc  ... pub_rec revol_bal revol_util  \
# 0  10+ years           RENT    117000.0  ...     0.0   36369.0       41.8
#
#    total_acc initial_list_status  application_type  mort_acc  \
# 0       25.0                   w        INDIVIDUAL       0.0
#
#    pub_rec_bankruptcies                                       address  \
# 0                   0.0  0174 Michelle Gateway\nMendozaberg, OK 22690
#
#    loan_status_Fully Paid
# 0                       1
#
# [1 rows x 26 columns]

# %%
df.isna().sum()
# Out:
# loan_amnt                     0
# term                          0
# int_rate                      0
# installment                   0
# grade                         0
# sub_grade                     0
# emp_title                 22927
# emp_length                18301
# home_ownership                0
# annual_inc                    0
# verification_status           0
# issue_d                       0
# purpose                       0
# dti                           0
# earliest_cr_line              0
# open_acc                      0
# pub_rec                       0
# revol_bal                     0
# revol_util                  276
# total_acc                     0
# initial_list_status           0
# application_type              0
# mort_acc                  37795
# pub_rec_bankruptcies        535
# address                       0
# loan_status_Fully Paid        0
# dtype: int64

# %%
df.corr(numeric_only=True)
# Out:
#                         loan_amnt      term  int_rate  installment  \
# loan_amnt                1.000000  0.393862  0.168921     0.953929
# term                     0.393862  1.000000  0.434594     0.153378
# int_rate                 0.168921  0.434594  1.000000     0.162758
# installment              0.953929  0.153378  0.162758     1.000000
# annual_inc               0.336887  0.060330 -0.056771     0.330381
# dti                      0.016636  0.036508  0.079038     0.015786
# open_acc                 0.198556  0.079575  0.011649     0.188973
# pub_rec                 -0.077779 -0.018758  0.060986    -0.067892
# revol_bal                0.328320  0.084787 -0.011280     0.316455
# revol_util               0.099911  0.055166  0.293659     0.123915
# total_acc                0.223886  0.101346 -0.036404     0.202430
# mort_acc                 0.222315  0.096220 -0.082583     0.193694
# pub_rec_bankruptcies    -0.106539 -0.019826  0.057450    -0.098628
# loan_status_Fully Paid  -0.059836 -0.173246 -0.247758    -0.041082
#
#                         annual_inc       dti  open_acc   pub_rec  revol_bal  \
# loan_amnt                 0.336887  0.016636  0.198556 -0.077779   0.328320
# term                      0.060330  0.036508  0.079575 -0.018758   0.084787
# int_rate                 -0.056771  0.079038  0.011649  0.060986  -0.011280
# installment               0.330381  0.015786  0.188973 -0.067892   0.316455
# annual_inc                1.000000 -0.081685  0.136150 -0.013720   0.299773
# dti                      -0.081685  1.000000  0.136181 -0.017639   0.063571
# open_acc                  0.136150  0.136181  1.000000 -0.018392   0.221192
# pub_rec                  -0.013720 -0.017639 -0.018392  1.000000  -0.101664
# revol_bal                 0.299773  0.063571  0.221192 -0.101664   1.000000
# revol_util                0.027871  0.088375 -0.131420 -0.075910   0.226346
# total_acc                 0.193023  0.102128  0.680728  0.019723   0.191616
# mort_acc                  0.236320 -0.025439  0.109205  0.011552   0.194925
# pub_rec_bankruptcies     -0.050162 -0.014558 -0.027732  0.699408  -0.124532
# loan_status_Fully Paid    0.053432 -0.062413 -0.028012 -0.019933   0.010892
#
#                         revol_util  total_acc  mort_acc  pub_rec_bankruptcies  \
# loan_amnt                 0.099911   0.223886  0.222315             -0.106539
# term                      0.055166   0.101346  0.096220             -0.019826
# int_rate                  0.293659  -0.036404 -0.082583              0.057450
# installment               0.123915   0.202430  0.193694             -0.098628
# annual_inc                0.027871   0.193023  0.236320             -0.050162
# dti                       0.088375   0.102128 -0.025439             -0.014558
# open_acc                 -0.131420   0.680728  0.109205             -0.027732
# pub_rec                  -0.075910   0.019723  0.011552              0.699408
# revol_bal                 0.226346   0.191616  0.194925             -0.124532
# revol_util                1.000000  -0.104273  0.007514             -0.086751
# total_acc                -0.104273   1.000000  0.381072              0.042035
# mort_acc                  0.007514   0.381072  1.000000              0.027239
# pub_rec_bankruptcies     -0.086751   0.042035  0.027239              1.000000
# loan_status_Fully Paid   -0.082373   0.017893  0.073111             -0.009383
#
#                         loan_status_Fully Paid
# loan_amnt                            -0.059836
# term                                 -0.173246
# int_rate                             -0.247758
# installment                          -0.041082
# annual_inc                            0.053432
# dti                                  -0.062413
# open_acc                             -0.028012
# pub_rec                              -0.019933
# revol_bal                             0.010892
# revol_util                           -0.082373
# total_acc                             0.017893
# mort_acc                              0.073111
# pub_rec_bankruptcies                 -0.009383
# loan_status_Fully Paid                1.000000

# %%
df["emp_title"].nunique()
# Out:
# 173105

# %%
df["emp_title"].value_counts()
# Out:
# emp_title
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: count, Length: 173105, dtype: int64

# %%
df.drop("emp_title", inplace=True, axis=1)

# %%
pp = df.sort_values(by="emp_length")

# %%
emplengthsort = pp["emp_length"].unique().tolist()

# %%
emplengthsort
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year',
#  nan]
